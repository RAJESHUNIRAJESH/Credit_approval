# %%
#from google.colab import files
#uploaded = files.upload()

# %%
import pandas as pd
import numpy as np

# %%
d1 = pd.read_csv("Credit_card.csv")
d2 = pd.read_csv("Credit_card_label.csv")
d1.head()
d2.head()
data1 = pd.merge(d1, d2, on='Ind_ID')
data1.head()
data = data1.copy()
data.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
data = data.rename(columns={'GENDER':'Gender','Propert_Owner':'Property_Owner','CHILDREN':'Children','EDUCATION':'Education','Birthday_count':'Age','Employed_days':'Experience'})

# %%
data['Age'] = abs(round((data['Age']/-365),0))
data['Experience'] = abs(round((data['Experience']/-365),0))

# %%
display(data)
# Out:
#        Ind_ID Gender Car_Owner Property_Owner  Children  Annual_income  \
# 0     5008827      M         Y              Y         0       180000.0
# 1     5009744      F         Y              N         0       315000.0
# 2     5009746      F         Y              N         0       315000.0
# 3     5009749      F         Y              N         0            NaN
# 4     5009752      F         Y              N         0       315000.0
# ...       ...    ...       ...            ...       ...            ...
# 1543  5028645      F         N              Y         0            NaN
# 1544  5023655      F         N              N         0       225000.0
# 1545  5115992      M         Y              Y         2       180000.0
# 1546  5118219      M         Y              N         0       270000.0
# 1547  5053790      F         Y              Y         0       225000.0
#
#                Type_Income                      Education  \
# ...

# %%
data['Experience'].replace(1001.0, 0,inplace=True)

# %%
data.nunique()
# Out:
# Ind_ID             1548
# Gender                2
# Car_Owner             2
# Property_Owner        2
# Children              6
# Annual_income       115
# Type_Income           4
# Education             5
# Marital_status        5
# Housing_type          6
# Age                  48
# Experience           39
# Mobile_phone          1
# Work_Phone            2
# Phone                 2
# EMAIL_ID              2
# Type_Occupation      18
# Family_Members        7
# label                 2
# dtype: int64

# %%
data.columns
# Out:
# Index(['Ind_ID', 'Gender', 'Car_Owner', 'Property_Owner', 'Children',
#        'Annual_income', 'Type_Income', 'Education', 'Marital_status',
#        'Housing_type', 'Age', 'Experience', 'Mobile_phone', 'Work_Phone',
#        'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members', 'label'],
#       dtype='object')

# %%
print(data.Gender.unique())
print(data.Car_Owner.unique())
print(data.Property_Owner.unique())
print(data.Children.unique())
print(data.Annual_income.unique())
print(data.Type_Income.unique())
print(data.Education.unique())
print(data.Marital_status.unique())
print(data.Housing_type.unique())
print(data.Age.unique())
print(data.Experience.unique())
print(data.Mobile_phone.unique())
print(data.Work_Phone.unique())
print(data.Phone.unique())
print(data.Type_Occupation.unique())
print(data.Family_Members.unique())
print(data.label.unique())
# Out:
# ['M' 'F' nan]
# ['Y' 'N']
# ['Y' 'N']
# [ 0  1  2  4  3 14]
# [ 180000.   315000.        nan  450000.    90000.   472500.   270000.
#   126000.   202500.   157500.   112500.   540000.   292500.   135000.
#    76500.   215100.   225000.    67500.   171000.   103500.    99000.
#   391500.    65250.    72900.   360000.   256500.   675000.   247500.
#    85500.   121500.   130500.   211500.    81000.    72000.   148500.
#   162000.   195750.   585000.   216000.   306000.   108000.    63000.
#    45000.   337500.   131400.   117000.   445500.   234000.  1575000.
#   144000.    67050.    73350.   193500.   900000.    94500.   198000.
#    54000.   166500.   167400.   153000.   423000.   243000.   283500.
#   252000.   495000.   612000.    36000.   139500.   133650.   427500.
#   261000.   231750.    90900.    45900.   119250.    58500.   328500.
#   787500.   594000.   119700.    69372.    37800.   387000.   207000.
#   189000.   333000.   105750.   382500.   141750.    40500.   405000.
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   Gender           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Property_Owner   1548 non-null   object
#  4   Children         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   Education        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Age              1526 non-null   float64
#  11  Experience       1548 non-null   float64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
# ...

# %%
data.describe(include='all')
# Out:
#               Ind_ID Gender Car_Owner Property_Owner     Children  \
# count   1.548000e+03   1541      1548           1548  1548.000000
# unique           NaN      2         2              2          NaN
# top              NaN      F         N              Y          NaN
# freq             NaN    973       924           1010          NaN
# mean    5.078920e+06    NaN       NaN            NaN     0.412791
# std     4.171759e+04    NaN       NaN            NaN     0.776691
# min     5.008827e+06    NaN       NaN            NaN     0.000000
# 25%     5.045070e+06    NaN       NaN            NaN     0.000000
# 50%     5.078842e+06    NaN       NaN            NaN     0.000000
# 75%     5.115673e+06    NaN       NaN            NaN     1.000000
# max     5.150412e+06    NaN       NaN            NaN    14.000000
#
#         Annual_income Type_Income                      Education  \
# count    1.525000e+03        1548                           1548
# ...

# %%
data.isnull().sum()
# Out:
# Ind_ID               0
# Gender               7
# Car_Owner            0
# Property_Owner       0
# Children             0
# Annual_income       23
# Type_Income          0
# Education            0
# Marital_status       0
# Housing_type         0
# Age                 22
# Experience           0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
import missingno as msno
msno.bar(data)
# Out:
# <Axes: >

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %%
data = data.dropna(subset = 'Gender')
data.Annual_income.fillna(data.Annual_income.mean(), inplace = True)
data.Age.fillna(data.Age.mean(), inplace = True)
data.Type_Occupation.fillna('Other', inplace = True)
# Out:
# <ipython-input-434-003d00e77654>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Annual_income.fillna(data.Annual_income.mean(), inplace = True)
# <ipython-input-434-003d00e77654>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Age.fillna(data.Age.mean(), inplace = True)
# <ipython-input-434-003d00e77654>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
data.drop_duplicates()
# Out:
#        Ind_ID Gender Car_Owner Property_Owner  Children  Annual_income  \
# 0     5008827      M         Y              Y         0  180000.000000
# 1     5009744      F         Y              N         0  315000.000000
# 2     5009746      F         Y              N         0  315000.000000
# 3     5009749      F         Y              N         0  190796.753953
# 4     5009752      F         Y              N         0  315000.000000
# ...       ...    ...       ...            ...       ...            ...
# 1543  5028645      F         N              Y         0  190796.753953
# 1544  5023655      F         N              N         0  225000.000000
# 1545  5115992      M         Y              Y         2  180000.000000
# 1546  5118219      M         Y              N         0  270000.000000
# 1547  5053790      F         Y              Y         0  225000.000000
#
#                Type_Income                      Education  \
# ...

# %%
import seaborn as sns
sns.boxplot(data.Children)
# Out:
# <Axes: ylabel='Children'>

# %%
Q1 = data.Children.quantile(0.25)
Q3 = data.Children.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(lower_bound)
print(upper_bound)
data[(data.Children < lower_bound) | (data.Children > upper_bound)]

data = data[(data.Children > lower_bound) & (data.Children < upper_bound)]
# Out:
# 1.0
# -1.5
# 2.5

# %%
sns.boxplot(data.Annual_income)
# Out:
# <Axes: ylabel='Annual_income'>

# %%
Q1 = data.Annual_income.quantile(0.25)
Q3 = data.Annual_income.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(lower_bound)
print(upper_bound)
data[(data.Annual_income < lower_bound) | (data.Annual_income > upper_bound)]

data = data[(data.Annual_income > lower_bound) & (data.Annual_income < upper_bound)]
# Out:
# 103500.0
# -33750.0
# 380250.0

# %%
sns.boxplot(data.Experience)
# Out:
# <Axes: ylabel='Experience'>

# %%
Q1 = data.Experience.quantile(0.25)
Q3 = data.Experience.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(lower_bound)
print(upper_bound)
data[(data.Experience < lower_bound) | (data.Experience > upper_bound)]

data = data[(data.Experience > lower_bound) & (data.Experience < upper_bound)]
# Out:
# 8.0
# -11.0
# 21.0

# %%
data.Age.unique()
# Out:
# array([51.        , 37.        , 43.97432521, 61.        , 52.        ,
#        46.        , 35.        , 33.        , 49.        , 44.        ,
#        60.        , 29.        , 36.        , 56.        , 58.        ,
#        65.        , 53.        , 64.        , 42.        , 30.        ,
#        50.        , 32.        , 26.        , 28.        , 45.        ,
#        67.        , 57.        , 59.        , 25.        , 38.        ,
#        31.        , 43.        , 40.        , 34.        , 47.        ,
#        41.        , 55.        , 63.        , 54.        , 62.        ,
#        27.        , 39.        , 48.        , 66.        , 23.        ,
#        68.        , 24.        , 22.        , 21.        ])

# %%
data['Age'] = round(data['Age'])
# Out:
# <ipython-input-443-177a0635b846>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Age'] = round(data['Age'])

# %%
data.head()
# Out:
#     Ind_ID Gender Car_Owner Property_Owner  Children  Annual_income  \
# 0  5008827      M         Y              Y         0  180000.000000
# 1  5009744      F         Y              N         0  315000.000000
# 2  5009746      F         Y              N         0  315000.000000
# 3  5009749      F         Y              N         0  190796.753953
# 4  5009752      F         Y              N         0  315000.000000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#     Age  Experience  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
sql_credit = data.to_csv('sql_credit.csv', index = False, header = True)

# %%
data = data.drop(['Ind_ID', 'Mobile_phone',	'Work_Phone',	'Phone',	'EMAIL_ID'], axis = 1)

# %%
data.head()
# Out:
#   Gender Car_Owner Property_Owner  Children  Annual_income  \
# 0      M         Y              Y         0  180000.000000
# 1      F         Y              N         0  315000.000000
# 2      F         Y              N         0  315000.000000
# 3      F         Y              N         0  190796.753953
# 4      F         Y              N         0  315000.000000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#     Age  Experience Type_Occupation  Family_Members  label
# 0  51.0         0.0           Other               2      1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in ['Gender', 'Car_Owner', 'Property_Owner', 'Type_Income', 'Education', 'Marital_status', 'Housing_type', 'Type_Occupation']:
    data[col] = le.fit_transform(data[col])

# %%
data.head()
# Out:
#    Gender  Car_Owner  Property_Owner  Children  Annual_income  Type_Income  \
# 0       1          1               1         0  180000.000000            1
# 1       0          1               0         0  315000.000000            0
# 2       0          1               0         0  315000.000000            0
# 3       0          1               0         0  190796.753953            0
# 4       0          1               0         0  315000.000000            0
#
#    Education  Marital_status  Housing_type   Age  Experience  Type_Occupation  \
# 0          1               1             1  51.0         0.0               12
# 1          1               1             1  37.0         2.0               12
# 2          1               1             1  44.0         2.0               12
# 3          1               1             1  37.0         2.0               12
# 4          1               1             1  37.0         2.0               12
#
#    Family_Members  label
# ...

# %%
print(data.Gender.skew())
print(data.Car_Owner.skew())
print(data.Property_Owner.skew())
print('Children_skew :',data.Children.skew())
print(data.Annual_income.skew())
print(data.Type_Income.skew())
print(data.Education.skew())
print('Marital_status_skew :',data.Marital_status.skew())
print('Housing_type_skew :',data.Housing_type.skew())
print(data.Age.skew())
print('Experience_skew :',data.Experience.skew())
print(data.Type_Occupation.skew())
print(data.Family_Members.skew())
print('label_skew :',data.label.skew())
# Out:
# 0.569338272922947
# 0.4297049061209287
# -0.6120303804171924
# Children_skew : 1.5223469193511612
# 0.6499925676512983
# -0.4337253703917148
# -0.8495510675724803
# Marital_status_skew : 1.2399119756327772
# Housing_type_skew : 3.3211074899998945
# 0.2117894906900166
# Experience_skew : 1.072357704129844
# -0.4272412187782398
# 0.619715168065089
# label_skew : 2.5439768919823726

# %%
#Children,Marital_Status,Housing_Type,Experience,label are left skewed

#from scipy.stats import boxcox

#for col in ['Children', 'Marital_status', 'Housing_type', 'Experience', 'label']:
#    data[col],_ = boxcox(data[col])

# %%
x = data.drop('label', axis = 1)
y = data['label']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

lr = LogisticRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

from sklearn.model_selection import cross_val_score
scores = cross_val_score(lr, x_train, y_train, cv = 5)
print(scores)
print(scores.mean())
# Out:
# 0.9061371841155235
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       251
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.91       277
#    macro avg       0.45      0.50      0.48       277
# weighted avg       0.82      0.91      0.86       277
#
# [0.89140271 0.89140271 0.89140271 0.88687783 0.88687783]
# 0.8895927601809955
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

from sklearn.model_selection import cross_val_score
scores = cross_val_score(dt, x_train, y_train, cv = 5)
print(scores)
print(scores.mean())
# Out:
# 0.8411552346570397
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       251
#            1       0.26      0.38      0.31        26
#
#     accuracy                           0.84       277
#    macro avg       0.60      0.64      0.61       277
# weighted avg       0.87      0.84      0.85       277
#
# [0.85520362 0.86877828 0.83710407 0.84615385 0.85520362]
# 0.8524886877828054

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

from sklearn.model_selection import cross_val_score
scores = cross_val_score(rf, x_train, y_train, cv = 5)
print(scores)
print(scores.mean())
# Out:
# 0.9422382671480144
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       251
#            1       1.00      0.38      0.56        26
#
#     accuracy                           0.94       277
#    macro avg       0.97      0.69      0.76       277
# weighted avg       0.95      0.94      0.93       277
#
# [0.91855204 0.91855204 0.91402715 0.90045249 0.92760181]
# 0.9158371040723982

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

from sklearn.model_selection import cross_val_score
scores = cross_val_score(knn, x_train, y_train, cv = 5)
print(scores)
print(scores.mean())
# Out:
# 0.8916967509025271
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       251
#            1       0.25      0.08      0.12        26
#
#     accuracy                           0.89       277
#    macro avg       0.58      0.53      0.53       277
# weighted avg       0.85      0.89      0.86       277
#
# [0.87782805 0.8959276  0.88687783 0.88687783 0.87330317]
# 0.8841628959276019

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

from sklearn.model_selection import cross_val_score
scores = cross_val_score(svc, x_train, y_train, cv = 5)
print(scores)
print(scores.mean())
# Out:
# 0.9061371841155235
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       251
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.91       277
#    macro avg       0.45      0.50      0.48       277
# weighted avg       0.82      0.91      0.86       277
#
# [0.89140271 0.89140271 0.89140271 0.88687783 0.88687783]
# 0.8895927601809955
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from xgboost import XGBClassifier
xg = XGBClassifier()
xg.fit(x_train, y_train)
y_pred = xg.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

from sklearn.model_selection import cross_val_score
scores = cross_val_score(xg, x_train, y_train, cv = 5)
print(scores)
print(scores.mean())
# Out:
# 0.9205776173285198
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       251
#            1       0.62      0.38      0.48        26
#
#     accuracy                           0.92       277
#    macro avg       0.78      0.68      0.72       277
# weighted avg       0.91      0.92      0.91       277
#
# [0.90950226 0.8959276  0.91855204 0.8959276  0.92307692]
# 0.9085972850678733

# %%
from sklearn.ensemble import GradientBoostingClassifier # Import the correct classifier
gb = GradientBoostingClassifier() # Instantiate the classifier
gb.fit(x_train, y_train)
y_pred = gb.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

from sklearn.model_selection import cross_val_score
scores = cross_val_score(gb, x_train, y_train, cv = 5)
print(scores)
print(scores.mean())
# Out:
# 0.9097472924187726
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       251
#            1       1.00      0.04      0.07        26
#
#     accuracy                           0.91       277
#    macro avg       0.95      0.52      0.51       277
# weighted avg       0.92      0.91      0.87       277
#
# [0.90045249 0.90045249 0.8959276  0.88687783 0.8959276 ]
# 0.8959276018099548

# %% [markdown]
# # **conclusion**
#
# Hence we got accuracy on different classification
#
# -logisitic regression got accuracy 90%
#
# -DecisionTree got accuracy 84%
#
# -Random Forest got accuracy 94%
#
# -KNeighborsClassifier got accuracy 89%
#
# -SVC got accuracy 90%
#
# -xg boosting got accuracy 92%
#
# -GradientBoostingClassifier got accuracy 90%
#
# After feature selection we used four machine learning models and achieved quite good accuracy 94% in Random Forest for predicting the credit card approval.
